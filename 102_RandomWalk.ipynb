# %% [markdown]
# <a href="https://colab.research.google.com/github/deguc/Shannon/blob/main/102_RandomWalk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

N = 200
steps = 1000

step = np.array([[-1,0],[1,0],[0,-1],[0,1]])
x = np.zeros((N,2))

fig = plt.figure()

plt.title('Random Waik')

R = int(np.ceil(np.sqrt(steps)*2))
plt.xlim(-R,R)
plt.ylim(-R,R)

scat = plt.scatter(x[:,0],x[:,1],alpha=0.4)


def update(frame):

    move = step[np.random.choice(4,N)]
    np.add(x,move,out=x)
    scat.set_offsets(x)

ani=FuncAnimation(fig,update,frames=steps,interval=50)
plt.show()
